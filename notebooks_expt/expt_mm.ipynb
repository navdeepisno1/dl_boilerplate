# %%
import torch
from torchvision import transforms as T

# %%
def get_image(a):
    return T.ToPILImage()(a)

img_size = 128
a = torch.ones(img_size,img_size)
img_1 = torch.triu(a)/3
img_2 = torch.tril(a)/3
img_3 = img_1@img_2
img_4 = img_2@img_1
img_5 = (img_1+img_2)/2

imgs = torch.concat([img_1,img_2,img_3,img_4,img_5],dim=1)
display(get_image(imgs))
# for img in imgs:
#     display(get_image(img))
# Out:
# <PIL.Image.Image image mode=L size=640x128>
